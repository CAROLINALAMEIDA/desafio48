# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('PDA_Lista_Instituicoes_Ensino_Superior_do_Brasil_EMEC.csv')
print(df.head())
# Out:
#    CODIGO_DA_IES                                        NOME_DA_IES  \
# 0          21995             Faculdade de Tecnologia Senac Curitiba
# 1           1768                         FACULDADE REGIONAL SERRANA
# 2           5701                    UNIVERSIDADE DO ESTADO DO AMAPÁ
# 3          23261       Faculdade São Judas de São Bernardo do Campo
# 4           4250  FACULDADE DE CIÊNCIAS GERENCIAIS ALVES FORTES ...
#
#            SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL FILANTROPICA  \
# 0            NaN          Privada           N            N            N
# 1         FUNPAC          Privada           N            N            N
# 2           UEAP          Pública           N            N            N
# 3            NaN          Privada           N            N            N
# 4  FACE ALFOR JF          Privada           N            N            N
#
#   ORGANIZACAO_ACADEMICA  CODIGO_MUNICIPIO_IBGE                MUNICIPIO  UF  \
# 0             Faculdade              4106902.0                 Curitiba  PR
# 1             Faculdade              3205069.0  Venda Nova do Imigrante  ES
# 2          Universidade              1600303.0                   Macapá  AP
# 3             Faculdade              3548708.0    São Bernardo do Campo  SP
# 4             Faculdade              3136702.0             Juiz de Fora  MG
#
#   SITUACAO_IES
# 0        Ativa
# 1      Extinta
# 2        Ativa
# 3        Ativa
# 4      Extinta

# %%
print(df.describe())
# Out:
#        CODIGO_DA_IES  CODIGO_MUNICIPIO_IBGE
# count    4328.000000           3.870000e+03
# mean     9118.568854           3.399418e+06
# std      8819.522630           9.539226e+05
# min         1.000000           1.100023e+06
# 25%      1684.500000           2.918407e+06
# 50%      4011.500000           3.306058e+06
# 75%     18164.250000           4.106902e+06
# max     27103.000000           5.300108e+06

# %%
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    CODIGO_DA_IES                                        NOME_DA_IES  \
# 0          21995             Faculdade de Tecnologia Senac Curitiba
# 1           1768                         FACULDADE REGIONAL SERRANA
# 2           5701                    UNIVERSIDADE DO ESTADO DO AMAPÁ
# 3          23261       Faculdade São Judas de São Bernardo do Campo
# 4           4250  FACULDADE DE CIÊNCIAS GERENCIAIS ALVES FORTES ...
#
#            SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL FILANTROPICA  \
# 0            NaN          Privada           N            N            N
# 1         FUNPAC          Privada           N            N            N
# 2           UEAP          Pública           N            N            N
# 3            NaN          Privada           N            N            N
# 4  FACE ALFOR JF          Privada           N            N            N
#
#   ORGANIZACAO_ACADEMICA  CODIGO_MUNICIPIO_IBGE                MUNICIPIO  UF  \
# 0             Faculdade              4106902.0                 Curitiba  PR
# 1             Faculdade              3205069.0  Venda Nova do Imigrante  ES
# 2          Universidade              1600303.0                   Macapá  AP
# 3             Faculdade              3548708.0    São Bernardo do Campo  SP
# 4             Faculdade              3136702.0             Juiz de Fora  MG
#
#   SITUACAO_IES
# 0        Ativa
# 1      Extinta
# 2        Ativa
# 3        Ativa
# 4      Extinta
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4328 entries, 0 to 4327
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CODIGO_DA_IES          4328 non-null   int64
#  1   NOME_DA_IES            4328 non-null   object
#  2   SIGLA                  3500 non-null   object
#  3   CATEGORIA_DA_IES       4328 non-null   object
#  4   COMUNITARIA            4328 non-null   object
#  5   CONFESSIONAL           4328 non-null   object
#  6   FILANTROPICA           4328 non-null   object
#  7   ORGANIZACAO_ACADEMICA  4328 non-null   object
#  8   CODIGO_MUNICIPIO_IBGE  3870 non-null   float64
#  9   MUNICIPIO              3870 non-null   object
#  10  UF                     3870 non-null   object
#  11  SITUACAO_IES           4328 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 405.9+ KB
# None
#        CODIGO_DA_IES  CODIGO_MUNICIPIO_IBGE
# count    4328.000000           3.870000e+03
# mean     9118.568854           3.399418e+06
# std      8819.522630           9.539226e+05
# min         1.000000           1.100023e+06
# 25%      1684.500000           2.918407e+06
# 50%      4011.500000           3.306058e+06
# 75%     18164.250000           4.106902e+06
# max     27103.000000           5.300108e+06

# %%
bolsas_por_estado = df['UF'].value_counts()
bolsas_por_estado.plot(kind='bar')
plt.xlabel('Estado')
plt.ylabel('Número de Bolsas')
plt.title('Distribuição de Bolsas por Estado')
plt.show()

# %%
bolsas_por_estado = df['UF'].value_counts()
bolsas_por_estado.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribuição de Bolsas por Estado')
plt.show()

# %%
from fpdf import FPDF

# %%
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()

# %%
pdf.set_font('Arial', 'B', 15)
pdf.cell(0, 10, 'Relatório Lista de Instiuições de Ensino Superior do Brasil', ln= True, align='C')
# Out:
# C:\Users\anaca\AppData\Local\Temp\ipykernel_9592\2632035358.py:1: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', 'B', 15)
# C:\Users\anaca\AppData\Local\Temp\ipykernel_9592\2632035358.py:2: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, 'Relatório Lista de Instiuições de Ensino Superior do Brasil', ln= True, align='C')
# False

# %%
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()

# %%
import matplotlib.pyplot as plt
from fpdf import FPDF


pdf = FPDF()


pdf.add_page()


bolsas_por_estado = df['UF'].value_counts()
plt.figure(figsize=(10, 6))
bolsas_por_estado.plot(kind='bar')
plt.xlabel('Estado')
plt.ylabel('Número de Bolsas')
plt.title('Distribuição de Bolsas por Estado')
plt.savefig('barras.png', bbox_inches='tight')
plt.close()


pdf.image('barras.png', x=10, y=10, w=180)


bolsas_por_estado = df['UF'].value_counts()
plt.figure(figsize=(10, 6))
bolsas_por_estado.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribuição de Bolsas por Estado')
plt.savefig('pizza.png', bbox_inches='tight')
plt.close()


pdf.image('pizza.png', x=10, y=100, w=180)


pdf.output('relatorio_bolsas.pdf', 'F')
# Out:
# C:\Users\anaca\AppData\Local\Temp\ipykernel_9592\2052101251.py:35: DeprecationWarning: "dest" parameter is deprecated since v2.2.0, unused and will soon be removed
#   pdf.output('relatorio_bolsas.pdf', 'F')
